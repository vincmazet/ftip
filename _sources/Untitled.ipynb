# %% [markdown]
# bonjour **gras** _italique_
#
# # Titre
# ## Sous titre
#
# par exemple, le signal $x(t) = \sin(2\pi f t)$.

# %%
a = 1
print(a)
# Out:
# 1

# %%
print(a)
# Out:
# 1

# %%
print(a)
# Out:
# 1

# %%
a = a + 1
